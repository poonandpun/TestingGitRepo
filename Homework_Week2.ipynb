# %% [markdown]
# ![Screenshot 2566-08-15 at 21.30.57.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2566-08-15 at 21.31.50.png](data:image/png;base64,...)

# %%
if __name__ == '__main__':
    N = int(input())
    result = []
    for i in range (N):
        receive = input().split()
        command = receive[0]
        if(command == "insert"):
            result.insert(int(receive[1]), int(receive[2]))
        elif(command == "print"):
            print(result)
        elif(command == "remove"):
            result.remove(int(receive[1]))
        ## Code here
# Out:
# 2
# insert 0 5
# print
# [5]
